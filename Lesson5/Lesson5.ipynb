# %% [markdown]
# <a href="https://colab.research.google.com/github/abrahamn3-prog/INFO-450/blob/main/Lesson5/Lesson5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = "https://raw.githubusercontent.com/abrahamn3-prog/INFO-450/refs/heads/main/Lesson5/soccer.json"
response=requests.get(url)
response.status_code
response.raise_for_status()
data=response.json()
data['matches'][104]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_442/707822377.py in <cell line: 0>()
#       4 response.raise_for_status()
#       5 data=response.json()
# ----> 6 data['matches'][104]
#
# IndexError: list index out of range
